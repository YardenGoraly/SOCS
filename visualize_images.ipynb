# %%
from matplotlib import pyplot as plt
import os
import numpy as np

 

image_path = os.path.join('teacher_student_data_npz-3', 'train', '1000.npz')
data = np.load(image_path)
print('here', data['teacher_masks'].shape)
image = data['rgb'][0][0]
plt.imshow(image, interpolation='nearest')
plt.show()
# Out:
# here (8, 128, 128)

# %%
teacher_mask = data['teacher_masks'][0]
plt.imshow(teacher_mask, interpolation='nearest')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 teacher_mask = data['teacher_masks'][0]
#       2 plt.imshow(teacher_mask, interpolation='nearest')
#       3 plt.show()
#
# File ~/anaconda3/envs/sam-track/lib/python3.9/site-packages/numpy/lib/npyio.py:263, in NpzFile.__getitem__(self, key)
#     261         return self.zip.read(key)
#     262 else:
# --> 263     raise KeyError(f"{key} is not a file in the archive")
#
# KeyError: 'teacher_masks is not a file in the archive'

# %%
import cv2

# Open the MP4 video file
cap = cv2.VideoCapture('fixed_converted_videos/train/4.mp4')

# Read the first frame of the video
ret, frame = cap.read()

plt.imshow(frame, interpolation='nearest')
plt.show()
